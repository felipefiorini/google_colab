# %% [markdown]
# <a href="https://colab.research.google.com/github/felipefiorini/google_colab/blob/main/Spark%5B244%5D_Files.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# instalar as dependências
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-2.4.4/spark-2.4.4-bin-hadoop2.7.tgz
# !tar xf spark-2.4.4-bin-hadoop2.7.tgz
# !pip install -q findspark

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.4-bin-hadoop2.7"
 
# tornar o pyspark "importável"
import findspark
findspark.init('spark-2.4.4-bin-hadoop2.7')

import pyspark
from pyspark import SparkContext as spark
from pyspark.sql import SparkSession, SQLContext
from pyspark import SparkFiles
from pyspark.sql import functions as F
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql.window import Window

spark = SparkSession.builder.enableHiveSupport().getOrCreate() # Creating Session
sc = spark.sparkContext                                        #Initialize Spark

# %%
# !mkdir /content/libs_teste

with open('/content/libs_teste/lib1.py', 'w') as writefile:
    writefile.write('''def libTeste(string):\n''')
    writefile.write('''    print('Teste lib_1 ok! - ' + string)''')

with open('/content/libs_teste/lib2.py', 'w') as writefile:
    writefile.write('''def libTeste(string):\n''')
    writefile.write('''    print('Teste lib_2 ok! - ' + string)''')
# Out:
# mkdir: cannot create directory ‘/content/libs_teste’: File exists

# %%
sc.addFile('/content/libs_teste/lib1.py')
sc.addFile('/content/libs_teste/lib2.py')

import lib1 as l1
import lib2 as l2

# %%
l1.libTeste('lib1')
# Out:
# Teste lib_1 ok! 1- lib1

# %%
l2.libTeste('lib2')
# Out:
# Teste lib_2 ok! - lib2

# %%
spark.stop
# Out:
# <bound method SparkSession.stop of <pyspark.sql.session.SparkSession object at 0x7f546a5c9310>>
